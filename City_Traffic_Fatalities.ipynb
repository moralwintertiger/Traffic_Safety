# %%
import pandas as pd
import numpy as np
import pylab

# %%
fatalities_by_city_total = {'NYC':3.21, 'LA':6.27, 'Chicago':5.34, 'Houston':9.07,
                     'Philadelphia':6.91, 'Phoenix':10.14, 'San Antonio':9.54,
                     'San Diego':5.23, 'Dallas':10.96, 'San Jose': 4.27, 'Austin':9.02,
                     'Jacksonville':13.51, 'Indianapolis':9.22, 'San Francisco':3.51,
                     'Columbus':7.16, 'Fort Worth':7.58, 'Charlotte':7.87, 'Detroit':14.54,
                     'El Paso':8.03, 'Memphis':11.91, 'Boston':3.61, 'Seattle': 4.26, 
                     'Denver':5.68, 'Washington':2.37, 'Nashville':8.97, 'Baltimore':4.35,
                     'Louisville':9.75, 'Portland':5.31, 'OKC':13.85, 'Milwaukee':7.01, 
                     'Las Vegas':9.89, 'Albuquerque':9, 'Tucson':10.49, 'Fresno':5.73, 
                     'Sacramento':5.68, 'Long Beach':8.12, 'Kansas City':14.65, 'Mesa': 6.64,
                     'Virginia Beach':3.36, 'Atlanta': 9.69}

# %%
fatalities_by_city_ped = {'NYC':1.52, 'LA':2.57, 'Chicago':1.73, 'Houston':2.13,
                     'Philadelphia':2, 'Phoenix':2.62, 'San Antonio':2.68,
                     'San Diego':1.64, 'Dallas':3.22, 'San Jose': 1.22, 'Austin':2.97,
                     'Jacksonville':3.23, 'Indianapolis':1.8, 'San Francisco':1.7,
                     'Columbus':.99, 'Fort Worth':2.57, 'Charlotte':2.84, 'Detroit':3.99,
                     'El Paso':3.12, 'Memphis':1.68, 'Boston':.79, 'Seattle': 1.42, 
                     'Denver':2.84, 'Washington':1.11, 'Nashville':2.24, 'Baltimore':.97,
                     'Louisville':.99, 'Portland':2.32, 'OKC':3.34, 'Milwaukee':1.84, 
                     'Las Vegas':2.51, 'Albuquerque':3.24, 'Tucson':2.1, 'Fresno':2.77, 
                     'Sacramento':1.26, 'Long Beach':2.99, 'Kansas City':2.8, 'Mesa': 1.77,
                     'Virginia Beach':.67, 'Atlanta': 1.8}

# %%
party_by_city = {'NYC':61.6, 'LA':66.6, 'Chicago':63.7, 'Houston':48.5,
                     'Philadelphia':61.6, 'Phoenix':51.4, 'San Antonio':47.2,
                     'San Diego':56.6, 'Dallas':48.7, 'San Jose': 72.9, 'Austin':56.5,
                     'Jacksonville':43.4, 'Indianapolis':48.3, 'San Francisco':76.7,
                     'Charlotte':49.9, 'Detroit':52.5,
                     'El Paso':69, 'Memphis':54, 'Boston':62, 'Seattle': 62, 
                     'Denver':53.5, 'Washington':68.2, 'Nashville':44.2, 'Baltimore':55.8,
                     'Louisville':50.2, 'Portland':57.5, 'OKC':41.5,  
                     'Las Vegas':52.5, 'Tucson':54.3,  
                     'Sacramento':53,'Kansas City':45.9, 
                     'Virginia Beach':51, 'Atlanta': 52}

# %%
ped_fatalities_by_city_2016 = {'NYC':1.6, 'LA':3.27, 'Chicago':1.52, 'Houston':3.43,
                     'Philadelphia':2.74, 'Phoenix':5.57, 'San Antonio':4.29,
                     'San Diego':2.99, 'Dallas':4.32, 'San Jose': 2.05, 'Austin':3.16,
                     'Jacksonville':3.97, 'Indianapolis':2.34, 'San Francisco':1.61,
                     'Columbus':1.86, 'Fort Worth':3.4, 'Charlotte':2.61, 'Detroit':4.31,
                     'El Paso':3.37, 'Memphis':4.29, 'Boston':1.93, 'Seattle': 0.85, 
                     'Denver':2.74, 'Washington':1.17, 'Nashville':2.42, 'Baltimore':2.44,
                     'Louisville':2.76, 'Portland':2.19, 'OKC':4.39, 'Milwaukee':2.18, 
                     'Las Vegas':2.05, 'Albuquerque':5.54, 'Tucson':3.01, 'Fresno':1.15, 
                     'Sacramento':3.03, 'Long Beach':2.98, 'Kansas City':2.08, 'Mesa': 2.06,
                     'Virginia Beach':.44, 'Atlanta': 4.44}

# %%
fatalities_by_city_2016 = {'NYC':2.69, 'LA':7.92, 'Chicago':4.55, 'Houston':10.77,
                     'Philadelphia':6.44, 'Phoenix':13.93, 'San Antonio':13,
                     'San Diego':6.82, 'Dallas':14.42, 'San Jose': 5.85, 'Austin':9.07,
                     'Jacksonville':16.92, 'Indianapolis':11.23, 'San Francisco':3.22,
                     'Columbus':6.16, 'Fort Worth':9.83, 'Charlotte':11.04, 'Detroit':17.54,
                     'El Paso':9.81, 'Memphis':18.38, 'Boston':4.01, 'Seattle': 3.83, 
                     'Denver':7.79, 'Washington':3.96, 'Nashville':9.84, 'Baltimore':6.67,
                     'Louisville':14.12, 'Portland':6.72, 'OKC':13.63, 'Milwaukee':9.92, 
                     'Las Vegas':9.16, 'Albuquerque':16.81, 'Tucson':11.12, 'Fresno':2.49, 
                     'Sacramento':9.89, 'Long Beach':7.23, 'Kansas City':13.71, 'Mesa': 9.29,
                     'Virginia Beach':4.2, 'Atlanta': 13.97}

# %%
income_by_city = {'NYC':37447, 'LA':33496, 'Chicago':34269, 'Houston':31175,
                     'Philadelphia':26039, 'Phoenix':27999, 'San Antonio':24625,
                     'San Diego':39325, 'Dallas':32114, 'San Jose': 43593, 'Austin':40323,
                     'Jacksonville':28531, 'San Francisco':64597,
                     'Columbus':27544, 'Fort Worth':28174, 'Charlotte':37300, 'Detroit':17667,
                     'El Paso':21908, 'Memphis':24143, 'Boston':42236, 'Seattle': 55276, 
                     'Denver':42271, 'Washington':52500, 'Nashville':33028, 
                     'Indianapolis':27304
                     }

# %%
#build a new pandas dataframe from the party_by_city and fatalities data

party_dataframe = pd.DataFrame.from_dict(party_by_city, orient='index', columns=['percent blue voters'])
fatalities_dataframe_2016 = pd.DataFrame.from_dict(fatalities_by_city_2016, orient='index', columns=['total death rate'])
fatalities_peds_dataframe_2016 = pd.DataFrame.from_dict(ped_fatalities_by_city_2016, orient='index', columns=['ped death rate'])
income_dataframe = pd.DataFrame.from_dict(income_by_city, orient='index', columns=['income by city'])

# %%
vote_merged_df = pd.concat([party_dataframe, fatalities_dataframe_2016, fatalities_peds_dataframe_2016, income_dataframe], axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
#drop nan values:
vote_merged_df = vote_merged_df.dropna()
#sort df by total death rate:
#vote_merged_df = vote_merged_df.sort_values(by=['total death rate'])
vote_merged_df
# Out:
#                percent blue voters  total death rate  ped death rate  \
# Austin                        56.5              9.07            3.16
# Boston                        62.0              4.01            1.93
# Charlotte                     49.9             11.04            2.61
# Chicago                       63.7              4.55            1.52
# Dallas                        48.7             14.42            4.32
# Denver                        53.5              7.79            2.74
# Detroit                       52.5             17.54            4.31
# El Paso                       69.0              9.81            3.37
# Houston                       48.5             10.77            3.43
# Indianapolis                  48.3             11.23            2.34
# Jacksonville                  43.4             16.92            3.97
# LA                            66.6              7.92            3.27
# Memphis                       54.0             18.38            4.29
# ...

# %%
#sort by total death rate
vote_merged_df = vote_merged_df.sort_values(by='total death rate')

# %%
x = vote_merged_df['percent blue voters']
y = vote_merged_df['total death rate']
y2 = vote_merged_df['ped death rate']
y3 = vote_merged_df['income by city']

# %%
#plot death rate by city, overall and for pedestrians

plt.figure(figsize=(10,10))
plt.barh(vote_merged_df.index, y, alpha=.75, color='black')
plt.barh(10,vote_merged_df.loc['LA'][1], alpha=.75, color='red')
plt.title('2016 Collision Death Rate by City')
plt.xlabel('Collision deaths per 100k people')
plt.gca().xaxis.grid(True)
plt.savefig('2016_Collision_Death_Rate.png')

# %%
vote_merged_df = vote_merged_df.sort_values(by='ped death rate')
x = vote_merged_df['percent blue voters']
y = vote_merged_df['total death rate']
y2 = vote_merged_df['ped death rate']
y3 = vote_merged_df['income by city']

plt.figure(figsize=(10,10))
plt.barh(vote_merged_df.index, y2, alpha=.75, color='black')
plt.barh(14,vote_merged_df.loc['LA'][2], alpha=.75, color='red')
plt.title('2016 Pedestrian Death Rate by City')
plt.xlabel('Pedestrian deaths per 100k people')
plt.gca().xaxis.grid(True)

# %%
#plot death rate as a function of hillary votes

plt.figure(figsize=(16,10))
plt.scatter(x,y,c='black')
plt.scatter(merged_df.loc['LA']['percent blue voters'], merged_df.loc['LA']['total death rate'],  color='red', marker='D')
plt.ylabel('Collision Death Rate per 100k People')
plt.xlabel('Percent Hillary Voters')
plt.title('Death Rate as a Function of Blue Vote')
z = np.polyfit(merged_df['percent blue voters'], merged_df['total death rate'], 1)
p = np.poly1d(z)
plt.plot(merged_df['percent blue voters'],p(merged_df['percent blue voters']),"r--")

for i, txt in enumerate(vote_merged_df.index):
    plt.annotate(txt, ((x[i]+.3), (y[i]+.1)), fontsize=7.5)
plt.savefig('Death_Rate_Hillary.png')

# %%
corr1 = np.corrcoef(x,y)
corr2 = np.corrcoef(y,y3)
print(corr1)
print(corr2)
# Out:
# [[ 1.        -0.6994577]
#  [-0.6994577  1.       ]]
# [[ 1.         -0.72990338]
#  [-0.72990338  1.        ]]

# %%
#plot death rate as a function of income

plt.figure(figsize=(16,10))
plt.scatter(y3,y,c='black')
plt.scatter(y3.loc['LA'], y.loc['LA'],  color='red', marker='D')
plt.ylabel('Collision Death Rate per 100k People')
plt.xlabel('Per Capita Income')
plt.title('Death Rate as a Function of Per Capita Income')
z = np.polyfit(y3, y, 1)
p = np.poly1d(z)
plt.plot(y3,p(y3),"r--")
for i, txt in enumerate(vote_merged_df.index):
    plt.annotate(txt, ((y3[i]+.3), (y[i]+.3)), fontsize=7.5)
plt.savefig('Death_Rate_Income.png')

# %%
corr = np.corrcoef(x,y)
corr
# Out:
# array([[ 1.       , -0.6994577],
#        [-0.6994577,  1.       ]])

# %%
#plot for peds only

plt.figure(figsize=(8,5))
plt.scatter(x, y2, alpha=.75, c='black')
plt.scatter(merged_df.loc['LA']['percent blue voters'], merged_df.loc['LA']['ped death rate'],  color='red', marker='D')
plt.ylabel('Collision Death Rate per 100k People')
plt.xlabel('Percent Hillary Voters')
plt.title('Death Rate as a Function of Blue Vote')
z = np.polyfit(x, y2, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

# %%
# Out:
# array([[ 1.        , -0.44074369],
#        [-0.44074369,  1.        ]])

# %%
plt.figure(figsize=(10,10))
plt.barh(fatalities_cities, fatalities_rates, alpha=.75, color='black')
plt.barh(fatalities_cities[14], fatalities_rates[14], alpha=.75, color='red')
plt.title('Collision death rate, per 100k people')
# Out:
# Text(0.5, 1.0, 'Collision death rate, per 100k people')

# %%
fatalities_cities[39]
# Out:
# 'Kansas City'

# %%
plt.figure(figsize=(10,10))
plt.barh(fatalities_cities, fatalities_rates, alpha=.75, color='black')
plt.title('Collision death rate, per 100k people')
# Out:
# Text(0.5, 1.0, 'Collision death rate, per 100k people')

# %%
plt.figure(figsize=(10,10))
plt.barh(fatalities_cities_peds, fatalities_peds_rates, alpha=.75, color='black')
plt.title('Pedestrian death rate, per 100k people')
# Out:
# Text(0.5, 1.0, 'Pedestrian death rate, per 100k people')

# %%
#https://www.statista.com/statistics/205618/per-capita-income-in-the-top-20-most-populated-cities-in-the-us/

income_by_city = {'NYC':37447, 'LA':33496, 'Chicago':34269, 'Houston':31175,
                     'Philadelphia':26039, 'Phoenix':27999, 'San Antonio':24625,
                     'San Diego':39325, 'Dallas':32114, 'San Jose': 43593, 'Austin':40323,
                     'Jacksonville':28531, 'San Francisco':64597,
                     'Columbus':27544, 'Fort Worth':28174, 'Charlotte':37300, 'Detroit':17667,
                     'El Paso':21908, 'Memphis':24143, 'Boston':42236, 'Seattle': 55276, 
                     'Denver':42271, 'Washington':52500, 'Nashville':33028, 
                     'Indianapolis':27304
                     }

# %%
#compare collision data from 2012 to 2016

df_2012 = pd.DataFrame.from_dict(fatalities_by_city_total, orient='index', columns=['Collision_Death_Rate_2012'])
df_2016 = pd.DataFrame.from_dict(fatalities_by_city_2016, orient='index', columns=['Collision_Death_Rate_2016'])
collision_df = pd.concat([df_2012, df_2016], axis=1)

# %%
#collision_df['percent_change'] = ([collision_df['Collision_Death_Rate_2016']/collision_df['Collision_Death_Rate_2012'] for i in collision_df.index]

# %%
collision_df['percent_change'] = (collision_df['Collision_Death_Rate_2016']/collision_df['Collision_Death_Rate_2012']*100)-100

# %%
collision_df_percent_rank = collision_df.sort_values(by='percent_change')

# %%
collision_df_percent_rank
# Out:
#                 Collision_Death_Rate_2012  Collision_Death_Rate_2016  \
# Fresno                               5.73                       2.49
# NYC                                  3.21                       2.69
# Chicago                              5.34                       4.55
# Columbus                             7.16                       6.16
# Long Beach                           8.12                       7.23
# Seattle                              4.26                       3.83
# San Francisco                        3.51                       3.22
# Las Vegas                            9.89                       9.16
# Philadelphia                         6.91                       6.44
# Kansas City                         14.65                      13.71
# OKC                                 13.85                      13.63
# Austin                               9.02                       9.07
# Tucson                              10.49                      11.12
# ...

# %%
plt.figure(figsize=(10,10))
plt.barh(collision_df_percent_rank.index, collision_df_percent_rank['percent_change'], alpha=.75, color='black')
plt.barh(21,collision_df_percent_rank.loc['LA'][2], alpha=.75, color='red')

plt.xlabel('Percent Change from 2012 to 2016 in Collision Fatality Rate')



plt.title('Change in Collision Death Rate 2012-2016, by City')
plt.vlines(0, 10, 10)

# %%
vote_merged_df['percent_change'] = collision_df_percent_rank['percent_change']
vote_merged_df2 = vote_merged_df.sort_values(by='percent_change')

# %%
plt.figure(figsize=(10,10))
plt.barh(vote_merged_df2.index, vote_merged_df2['percent_change'], alpha=.75, color='black')
#plt.scatter(13,vote_merged_df2.loc['LA'][4], alpha=.75, color='red')

plt.xlabel('Percent Change from 2012 to 2016 in Collision Fatality Rate')
plt.xlim(-25, 100)


plt.title('Change in Collision Death Rate 2012-2016, by City')
# Out:
# Text(0.5, 1.0, 'Change in Collision Death Rate 2012-2016, by City')

# %%
plt.figure(figsize=(10,10), dpi=80)
plt.scatter(vote_merged_df2['percent_change'], vote_merged_df2.index, alpha=1, s=50, color='black')
plt.scatter(vote_merged_df2.loc['LA'][4],13, alpha=.75, color='red')

plt.xlabel('Percent Increase from 2012 to 2016 in Collision Fatality Rate')
plt.xlim(-25, 100)


plt.title('Change in Collision Death Rate 2012-2016, by City')
#plt.gca().xaxis.grid(True)
plt.grid()
plt.savefig('Change_2012_to_2016.png')

# %%
fatality_rate = [1.31, 1.35, 1.41, 1.37, 1.22, 1.25, 1.33, 1.32, 1.09, 1.16, 1.17, 1.12, .98, 1.09, 1.18, 1.14, .98, 1.09, 
                1.18, 1.17, 1.08, 1.12, 1.21, 1.16, 1.04, 1.07, 1.17, 1.15, .99, 1.03, 1.11, 1.17, 1.03, 1.08, 1.2, 1.21
                1.11, 
                 1.16, 1.23, 1.27, 1.12, 1.12, 1.2, 1.18, 1.11, 1.12, 1.18, 1.15]
# Out:
#   File "<ipython-input-696-b3ce142fd6c5>", line 3
#     1.11,
#        ^
# SyntaxError: invalid syntax

# %%
fatality_rate = [1.31, 1.35, 1.41, 1.37, 1.22, 1.25, 1.33, 1.32, 1.09, 1.16, 1.17, 1.12, .98, 1.09, 1.18, 1.14, .98, 1.09, 
                1.18, 1.17, 1.08, 1.12, 1.21, 1.16, 1.04, 1.07, 1.17, 1.15, .99, 1.03, 1.11, 1.17, 1.03, 1.08, 1.2, 1.21, 1.11, 
                 1.16, 1.23, 1.27, 1.12, 1.12, 1.2, 1.18, 1.11, 1.12, 1.18, 1.15]

# %%
quarters = ['2007Q1', '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4', '2097Q1', '2009Q2', '2009Q3', '2009Q4',
           '2010Q1', '2010Q2', '2010Q3', '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', 
           '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', 
           '2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1', '2018Q2', '2018Q3', '2018Q4']

# %%
plt.figure(figsize=(10,10))
plt.barh(quarters, fatality_rate)
# Out:
# <BarContainer object of 48 artists>

# %%
1975 45,087 70,435 64.01 9,356 59,233 15.80 54,445 129,668 41.99
1976 45,091 72,452 62.24 9,953 61,458 16.19 55,045 133,910 41.11
1977 48,548 74,385 65.27 10,775 63,591 16.94 59,324 137,976 43.00
1978 51,665 75,504 68.43 11,221 65,177 17.22 62,887 140,681 44.70
1979 52,208 76,458 68.28 11,308 66,695 16.95 63,518 143,152 44.37
1980 50,921 77,135 66.02 11,353 68,067 16.68 62,277 145,202 42.89
1981 49,838 77,831 64.03 11,396 69,142 16.48 61,238 146,972 41.67
1982 43,877 78,484 55.91 10,579 71,627 14.77 54,462 150,111 36.28
1983 42,329 80,823 52.37 10,854 73,440 14.78 53,184 154,263 34.48
1984 44,213 80,916 54.64 11,806 74,398 15.87 56,022 155,315 36.07
1985 44,290 81,537 54.32 12,031 75,231 15.99 56,322 156,769 35.93
1986 46,083 82,740 55.70 12,603 76,651 16.44 58,688 159,390 36.82
1987 46,337 83,939 55.20 13,492 77,789 17.34 59,829 161,728 36.99
1988 46,840 84,099 55.70 13,814 78,661 17.56 60,658 162,760 37.27
1989 44,941 85,356 52.65 13,927 80,160 17.37 58,870 165,516 35.57
1990 43,802 85,769 51.07 13,586 81,203 16.73 57,393 166,972 34.37
1991 40,288 86,630 46.51 12,716 82,300 15.45 53,007 168,930 31.38
1992 38,186 88,363 43.21 12,492 84,716 14.75 50,682 173,079 29.28
1993 39,118 87,974 44.47 12,960 85,138 15.22 52,080 173,112 30.08
1994 39,784 89,165 44.62 13,449 86,183 15.61 53,238 175,347 30.36
1995 40,799 89,184 45.75 14,043 87,386 16.07 54,847 176,570 31.06
1996 40,899 90,503 45.19 14,723 89,007 16.54 55,624 179,510 30.99
1997 40,594 91,888 44.18 14,816 90,789 16.32 55,412 182,677 30.33
1998 40,433 93,023 43.47 14,967 91,805 16.30 55,404 184,828 29.98
1999 40,639 94,149 43.16 14,717 92,988 15.83 55,359 187,137 29.58
2000 41,443 95,782 43.27 14,682 94,816 15.48 56,126 190,598 29.45
2001 41,548 95,779 43.38 14,829 95,471 15.53 56,380 191,250 29.48
2002 41,995 97,595 43.03 14,876 96,978 15.34 56,874 194,574 29.23
2003 42,177 98,209 42.95 15,106 97,919 15.43 57,285 196,128 29.21
2004 41,876 99,559 42.06 15,272 99,305 15.38 57,152 198,864 28.74
2005 42,947 100,240 42.84 14,967 100,285 14.92 57,921 200,525 28.88
2006 41,912 101,010 41.49 14,661 101,589 14.43 56,577 202,599 27.93
2007 40,764 102,338 39.83 14,101 103,152 13.67 54,872 205,490 26.70
2008 36,825 103,449 35.60 12,536 104,537 11.99 49,369 207,986 23.74
2009 32,690 104,056 31.42 11,797 105,153 11.22 44,492 209,209 21.27
2010 31,897 104,175 30.62 11,796 105,542 11.18 43,697 209,717 20.84
2011 31,771 104,720 30.34 11,227 106,794 10.51 43,001 211,514 20.33
2012 33,209 104,920 31.65 11,557 106,767 10.82 44,773 211,688 21.15
2013 32,457 104,976 30.92 11,382 107,121 10.63 43,849 212,097 20.67
2014 32,462 105,876 30.66 11,250 108,154 10.40 43,721 214,030 20.43
2015 35,679 107,617 33.15 12,332 110,402 11.17 48,029 218,019 22.03
2016 37,352 109,556 34.09 13,208 112,093 11.78 50,581 221,649 22.82
# Out:
#   File "<ipython-input-721-03b4ab339962>", line 1
#     1975 45,087 70,435 64.01 9,356 59,233 15.80 54,445 129,668 41.99
#           ^
# SyntaxError: invalid syntax

# %%
##drivers invovled in crashes by sex, p23 of the DOT report
males_dict = {'1981': 64.03, '1982': 55.91, '1983': 52.37, '1984': 54.64, '1985': 54.32, 
              '1986': 55.7, '1987':55.2, '1988': 55.7, '1989': 52.65, '1990':51.07, 
              '1991':46.51, '1992': 43.21, '1993': 44.47, '1994': 44.62, '1995': 45.75,
              '1996': 45.19, '1997': 44.18, '1998': 43.47, '1999': 43.16, '2000':43.27, 
              '2001': 43.38, '2002': 43.03, '2003': 42.95, '2004': 42.06, '2005': 42.84, 
              '2006': 41.49, '2007': 39.83, '2008': 35.6, '2009': 31.42, '2010': 30.62, 
              '2011': 30.34, '2012': 31.65, '2013': 30.92, '2014': 30.66, '2015': 33.15, '2016':34.09}

# %%
females_dict = {'1981': 16.48, '1982': 14.77, '1983':14.78, '1984': 15.87, '1985': 15.99, 
                '1986': 16.44, '1987': 17.34, '1988': 17.56, '1989': 17.37, '1990': 16.73, 
                '1991': 15.45, '1992': 14.75, '1993': 15.22, '1994': 15.61, '1995': 16.07, 
                '1996': 16.54, '1997': 16.32, '1998': 16.30, '1999': 15.83, '2000': 15.48, 
                '2001': 15.53, '2002': 15.34, '2003': 15.43, '2004': 15.38, '2005': 14.92, 
                '2006':14.43, '2007': 13.67, '2008': 11.99, '2009': 11.22, '2010': 11.18, 
                '2011': 10.51, '2012': 10.82, '2013': 10.63, '2014': 10.4, '2015': 11.17, '2016':11.78}

# %%
males_df = pd.DataFrame.from_dict(males_dict, orient='index', columns=['male_rate'])
#party_dataframe = pd.DataFrame.from_dict(party_by_city, orient='index', columns=['percent blue voters'])
females_df = pd.DataFrame.from_dict(females_dict, orient='index', columns=['female_rate'])

# %%
unisex_df = pd.concat([males_df, females_df], axis=1)
#collision_df = pd.concat([df_2012, df_2016], axis=1)

# %%
unisex_df
# Out:
#       male_rate  female_rate
# 1981      64.03        16.48
# 1982      55.91        14.77
# 1983      52.37        14.78
# 1984      54.64        15.87
# 1985      54.32        15.99
# 1986      55.70        16.44
# 1987      55.20        17.34
# 1988      55.70        17.56
# 1989      52.65        17.37
# 1990      51.07        16.73
# 1991      46.51        15.45
# 1992      43.21        14.75
# 1993      44.47        15.22
# 1994      44.62        15.61
# 1995      45.75        16.07
# 1996      45.19        16.54
# 1997      44.18        16.32
# 1998      43.47        16.30
# 1999      43.16        15.83
# 2000      43.27        15.48
# 2001      43.38        15.53
# 2002      43.03        15.34
# 2003      42.95        15.43
# 2004      42.06        15.38
# 2005      42.84        14.92
# 2006      41.49        14.43
# 2007      39.83        13.67
# 2008      35.60        11.99
# 2009      31.42        11.22
# 2010      30.62        11.18
# 2011      30.34        10.51
# ...

# %%
plt.figure(figsize=(20,10), dpi=80)
plt.plot(unisex_df.index, unisex_df['male_rate'], color="red", linewidth=8, label='Male drivers')
plt.plot(unisex_df.index, unisex_df['female_rate'], color="blue", linewidth=9, label='Female drivers')
plt.rc('axes', labelsize=10)
plt.legend(prop={'size':20})

# %%
###can safety improvements account for this decrease in death rate? Or is it behavioral? IE
###have females and males seen a similar percentage decrease in death rate over this time?
